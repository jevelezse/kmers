# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy.random as np
import sys
reload(sys)  
sys.setdefaultencoding('utf8')
import matplotlib

# %matplotlib inline

# %%
# Location of file
Location = r'Speakersdescription.xlsx'

# Parse a specific sheet
df = pd.read_excel(Location)
df.dtypes
# Out:
# Descripción       object
# Email             object
# Nombre            object
# Support          float64
# Titulo            object
# Tipo              object
# Decision          object
# Observaciones     object
# Status            object
# Schedule          object
# Country           object
# dtype: object

# %%
columnas=["Nombre","Email","Decision"]
df1=df[columnas]

# %%
df1[(df1['Decision']=='ACCEPTED')]
# Out:
#                                  Nombre                          Email  \
# 1                        Paulo Alvarado      commonzenpython@gmail.com
# 4                           Camilo Nova       camilo.nova@axiacore.com
# 8                          Vera Mazhuga           vero4ka.ru@gmail.com
# 9                       Andrés Guijarro   ec.andres.guijarro@gmail.com
# 10                Jennifer Vélez Segura       jennifervs.bio@gmail.com
# 11                        Daniel Moreno    daniel.moreno@mercadoni.com
# 14                         pedro rivera        pedro.rivera@jpt-la.com
# 18                     Vinicius Pacheco               vfpweb@gmail.com
# 19                       Fabian Latorre  latorre.fabian@quantil.com.co
# 20        Alejandro Correa Bahnsen, PhD           al.bahnsen@gmail.com
# 22                     Cristian Salamea     cristian.salamea@gmail.com
# 24            Diego Camilo Peña Ramirez            nervencid@gmail.com
# ...

# %%
mails= df1[(df1['Decision']=='ACCEPTED')]
mails
# Out:
#                             Email  Decision
# 1       commonzenpython@gmail.com  ACCEPTED
# 4        camilo.nova@axiacore.com  ACCEPTED
# 8            vero4ka.ru@gmail.com  ACCEPTED
# 9    ec.andres.guijarro@gmail.com  ACCEPTED
# 10       jennifervs.bio@gmail.com  ACCEPTED
# 11    daniel.moreno@mercadoni.com  ACCEPTED
# 14        pedro.rivera@jpt-la.com  ACCEPTED
# 18               vfpweb@gmail.com  ACCEPTED
# 19  latorre.fabian@quantil.com.co  ACCEPTED
# 20           al.bahnsen@gmail.com  ACCEPTED
# 22     cristian.salamea@gmail.com  ACCEPTED
# 24            nervencid@gmail.com  ACCEPTED
# 25               rkuska@gmail.com  ACCEPTED
# 26            iscmariog@gmail.com  ACCEPTED
# 29              humitos@gmail.com  ACCEPTED
# 30    j.e.forero.romero@gmail.com  ACCEPTED
# 36             eshernan@gmail.com  ACCEPTED
# 38            mfcabrera@gmail.com  ACCEPTED
# 39               lennin@piensa.co  ACCEPTED
# 40           darialdo92@gmail.com  ACCEPTED
# ...

# %%
len(mails)
# Out:
# 32

# %%
columnas=["Email"]
email=mails[columnas]
email
# Out:
#                             Email
# 1       commonzenpython@gmail.com
# 4        camilo.nova@axiacore.com
# 8            vero4ka.ru@gmail.com
# 9    ec.andres.guijarro@gmail.com
# 10       jennifervs.bio@gmail.com
# 11    daniel.moreno@mercadoni.com
# 14        pedro.rivera@jpt-la.com
# 18               vfpweb@gmail.com
# 19  latorre.fabian@quantil.com.co
# 20           al.bahnsen@gmail.com
# 22     cristian.salamea@gmail.com
# 24            nervencid@gmail.com
# 25               rkuska@gmail.com
# 26            iscmariog@gmail.com
# 29              humitos@gmail.com
# 30    j.e.forero.romero@gmail.com
# 36             eshernan@gmail.com
# 38            mfcabrera@gmail.com
# 39               lennin@piensa.co
# 40           darialdo92@gmail.com
# 41                 ariel@autti.co
# 42             goanpeca@gmail.com
# 43                jorge@piensa.co
# 47          cgarcia.e88@gmail.com
# 48       juanpablo@jpscaletti.com
# 55               wayner@piensa.co
# ...

# %%
email.to_csv("emails.csv", header=False,index=False,line_terminator=',')
